# %% [markdown]
# ## Important parameters
# <br>xt_ocean: longitude, length 3600
# <br>yt_ocean: latitude, length 1500
# <br> [mind map](https://miro.com/app/board/o9J_lM4N1Pg=/?fromRedirect=1)

# %%
import netCDF4 as nc4
from tensorflow import keras
import xarray,numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from tensorflow.keras import layers

# %% [markdown]
# # Load data

# %%
import glob
input_data_split = []
for np_name in glob.glob('../raw data/128/dataset_128_N102/*.np[yz]'):
    input_data_split.append(np.load(np_name))
input_data_split = np.array(input_data_split)

# %% [markdown]
# # Fix Missing Value

# %%
def fix_missing_value(input_data):
    """
    input 3d matrix
    """
    for i in range(0,len(input_data)):
        arr = input_data[i]
        arr[np.isnan(arr)] = 0
    return input_data

# %% [markdown]
# # Min Max Scaling

# %%
def min_max_scale(input_data, max_value, min_value):
    """
    input 3d matrix
    """
    for i in range(len(input_data)):
        input_data[i] = (input_data[i] - min_value)/(max_value - min_value)
    return input_data

# %% [markdown]
# # Preprocessing

# %%
import random
n = 3000 # sample size
random.seed(7)
input_data_split = np.array(random.sample(input_data_split.tolist(),n))
input_data_split.shape
# Out:
# (3000, 128, 128, 1)

# %%
input_data_split = fix_missing_value(input_data_split)
max_value = np.amax(input_data_split)
min_value = np.amin(input_data_split)
input_data_split_scaled = min_max_scale(input_data_split, max_value, min_value)

# %%
input_data_split_scaled.shape
# Out:
# (3000, 128, 128, 1)

# %% [markdown]
# # split train set & validation set

# %%
train_set, test_set = train_test_split(input_data_split, test_size=0.3333333, random_state=26)

train_set_scaled, test_set_scaled = train_test_split(input_data_split_scaled, test_size=0.3333333, random_state=26)
np.array(train_set_scaled).shape
# Out:
# (2000, 128, 128, 1)

# %% [markdown]
# # Autoencoder

# %%
lat = 128 # chunk size
long = 128 # chunk size

input_img = keras.Input(shape=(lat, long,1))

x = layers.Conv2D(64,(2,2), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (2,2), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(16, (2,2), activation='relu', padding='same')(x)

x = layers.Conv2D(8, (2,2), activation='relu', padding='same')(x)
encoded = layers.Conv2D(4, (2,2), activation='relu',strides=(1,1), padding='same')(x)

x = layers.Conv2DTranspose(8, (4, 4), strides=(1, 1),activation='relu', padding='same')(encoded)
x = layers.Conv2DTranspose(16, (4, 4), strides=(2, 2),activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(32, (4, 4), strides=(2, 2),activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(64, (4, 4), strides=(1, 1), activation='relu', padding='same')(x)
x = layers.Conv2DTranspose(64, (4, 4), strides=(1, 1),activation='relu', padding='same')(x)
decoded = layers.Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 64)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        8224
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 16)        2064
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 8)         520
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 4)         132
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 8)         520
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 64, 64, 16)        2064
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 128, 128, 32)      8224
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 128, 128, 64)      32832
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 128, 128, 64)      65600
# _________________________________________________________________
# conv2d_transpose_5 (Conv2DTr (None, 128, 128, 1)       577
# =================================================================
# Total params: 121,077
# Trainable params: 121,077
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = autoencoder.fit(train_set_scaled, train_set_scaled,
                epochs=20, validation_data=(test_set_scaled, test_set_scaled))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 495s 8s/step - loss: 0.0159 - val_loss: 0.0046
# Epoch 2/20
# 63/63 [==============================] - 511s 8s/step - loss: 0.0020 - val_loss: 9.6041e-04
# Epoch 3/20
# 63/63 [==============================] - 511s 8s/step - loss: 7.3496e-04 - val_loss: 5.4295e-04
# Epoch 4/20
# 63/63 [==============================] - 513s 8s/step - loss: 5.5833e-04 - val_loss: 4.9150e-04
# Epoch 5/20
# 63/63 [==============================] - 523s 8s/step - loss: 4.3868e-04 - val_loss: 3.3655e-04
# Epoch 6/20
# 63/63 [==============================] - 519s 8s/step - loss: 3.8298e-04 - val_loss: 2.8378e-04
# Epoch 7/20
# 63/63 [==============================] - 517s 8s/step - loss: 3.2079e-04 - val_loss: 2.5705e-04
# Epoch 8/20
# 63/63 [==============================] - 516s 8s/step - loss: 3.0103e-04 - val_loss: 2.3385e-04
# Epoch 9/20
# 63/63 [==============================] - 512s 8s/step - loss: 2.8133e-04 - val_loss: 2.3426e-04
# Epoch 10/20
# 63/63 [==============================] - 516s 8s/step - loss: 2.7026e-04 - val_loss: 2.2862e-04
# Epoch 11/20
# 63/63 [==============================] - 513s 8s/step - loss: 2.2845e-04 - val_loss: 2.1824e-04
# Epoch 12/20
# 63/63 [==============================] - 508s 8s/step - loss: 2.5079e-04 - val_loss: 1.8182e-04
# Epoch 13/20
# 63/63 [==============================] - 393s 6s/step - loss: 2.4276e-04 - val_loss: 1.7664e-04
# Epoch 14/20
# 63/63 [==============================] - 320s 5s/step - loss: 1.9829e-04 - val_loss: 2.6204e-04
# Epoch 15/20
# 63/63 [==============================] - 326s 5s/step - loss: 1.8330e-04 - val_loss: 2.0421e-04
# Epoch 16/20
# 63/63 [==============================] - 332s 5s/step - loss: 2.5193e-04 - val_loss: 1.5651e-04
# Epoch 17/20
# 63/63 [==============================] - 340s 5s/step - loss: 1.5926e-04 - val_loss: 1.4839e-04
# Epoch 18/20
# 63/63 [==============================] - 329s 5s/step - loss: 1.7413e-04 - val_loss: 1.5291e-04
# Epoch 19/20
# 63/63 [==============================] - 323s 5s/step - loss: 1.7554e-04 - val_loss: 2.3926e-04
# Epoch 20/20
# 63/63 [==============================] - 327s 5s/step - loss: 1.6006e-04 - val_loss: 1.5436e-04

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
test_sample_index = 122

# select a sample
original_data = test_set[test_sample_index]
original_data.shape

test_data = (original_data - min_value)/(max_value - min_value) # preprocessing
test_data.shape

decoded_data = autoencoder.predict(np.expand_dims(test_data, 0)) 
decoded_data = decoded_data*(max_value-min_value) + min_value   # scale back

# %%
fig = plt.figure(figsize=(16,32)) # image
ax1 = fig.add_subplot(1,2,1) 
ax1.imshow(original_data,cmap='hot')
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(decoded_data.reshape(128,128),cmap='hot')

# %%
mse = np.square((original_data-decoded_data)).mean()
mse
# Out:
# 0.00015483686274610415

# %%
test_sample_index = 110

# select a sample
original_data = test_set[test_sample_index]
original_data.shape

test_data = (original_data - min_value)/(max_value - min_value) # preprocessing
test_data.shape

decoded_data = autoencoder.predict(np.expand_dims(test_data, 0)) 
decoded_data = decoded_data*(max_value-min_value) + min_value   # scale back

fig = plt.figure(figsize=(16,32)) # image
ax1 = fig.add_subplot(1,2,1) 
ax1.imshow(original_data,cmap='hot')
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(decoded_data.reshape(128,128),cmap='hot')

# %%
mse = np.square((original_data-decoded_data)).mean()
mse
# Out:
# 0.0002641801741140225

# %%
autoencoder.save("autoencoder(32,32,4) layer(7-6) sample(3000 single region) kernelSize(2 & 4)")
# Out:
# WARNING:tensorflow:From c:\users\yuxuan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\users\yuxuan\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: autoencoder(32,32,4) layer(7-6) sample(3000 single region) kernelSize(2 & 4)\assets
