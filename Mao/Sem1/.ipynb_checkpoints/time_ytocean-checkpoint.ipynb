# %% [markdown]
# # Notes
# ### 1. variable: eta_t
#     default fill value: -32,768
# #### (a) time_ytocean_arr\[0] contains missing values <br>
# ![time_ytocean_arr](images/time_ytocean_arr.png)
# #### (b) time_ytocean_arr.data\[0] fills the missing values with default '_FillValue: -32768' <br>
# ![time_ytocean_arr_data](images/time_ytocean_arr_data.png) <br>
# Q: -32768 is too large compare with other values (range between -2 to 0), so what is the resonable value to fill the missing value? mean? median?

# %%
import netCDF4 as nc4
import keras
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers.core import  Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %%
file_path =['C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_01.nc']
file_path.append('C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_02.nc')
file_path.append('C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_03.nc')
file_path.append('C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_04.nc')
# file_path.append('C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_05.nc')
# file_path.append('C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_06.nc')

# %%
file_path
# Out:
# ['C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_01.nc',
#  'C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_02.nc',
#  'C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_03.nc',
#  'C:/Users/Administrator/OneDrive - The University of Melbourne/capstone/data/OFAM_2017/ocean_eta_t/ocean_eta_t_2000_04.nc']

# %%
ds = nc4.MFDataset(file_path)
eta_t_arr = ds.variables['eta_t'][:]

# %%
ds.variables
# Out:
# {'xt_ocean': <class 'netCDF4._netCDF4.Variable'>
#  float64 xt_ocean(xt_ocean)
#      long_name: tcell longitude
#      units: degrees_E
#      cartesian_axis: X
#      domain_decomposition: [   1 3600    1 1800]
#  unlimited dimensions:
#  current shape = (3600,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'yt_ocean': <class 'netCDF4._netCDF4.Variable'>
#  float64 yt_ocean(yt_ocean)
#      long_name: tcell latitude
#      units: degrees_N
#      cartesian_axis: Y
#      domain_decomposition: [   1 1500    1  150]
#  unlimited dimensions:
#  current shape = (1500,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'Time': <class 'netCDF4._netCDF4._Variable'>
#  float64 Time('Time',)
#      long_name: Time
#      units: days since 1979-01-01 00:00:00
#      cartesian_axis: T
#      calendar_type: GREGORIAN
#      calendar: GREGORIAN
#      bounds: Time_bounds
#  unlimited dimensions = ('Time',)
#  current size = (121,),
#  'nv': <class 'netCDF4._netCDF4.Variable'>
#  float64 nv(nv)
#  unlimited dimensions:
#  current shape = (2,)
#  filling on, default _FillValue of 9.969209968386869e+36 used,
#  'average_T1': <class 'netCDF4._netCDF4._Variable'>
#  float64 average_T1('Time',)
#      long_name: Start time for average period
#      units: days since 1979-01-01 00:00:00
#      missing_value: 1e+20
#      _FillValue: 1e+20
#  unlimited dimensions = ('Time',)
#  current size = (121,),
#  'average_T2': <class 'netCDF4._netCDF4._Variable'>
#  float64 average_T2('Time',)
#      long_name: End time for average period
#      units: days since 1979-01-01 00:00:00
#      missing_value: 1e+20
#      _FillValue: 1e+20
#  unlimited dimensions = ('Time',)
#  current size = (121,),
#  'average_DT': <class 'netCDF4._netCDF4._Variable'>
#  float64 average_DT('Time',)
#      long_name: Length of average period
#      units: days
#      missing_value: 1e+20
#      _FillValue: 1e+20
#  unlimited dimensions = ('Time',)
#  current size = (121,),
#  'Time_bounds': <class 'netCDF4._netCDF4._Variable'>
#  float64 Time_bounds('Time', 'nv')
#      long_name: Time axis boundaries
#      units: days
#      missing_value: 1e+20
#      _FillValue: 1e+20
#  unlimited dimensions = ('Time',)
#  current size = (121, 2),
#  'eta_t': <class 'netCDF4._netCDF4._Variable'>
#  int16 eta_t('Time', 'yt_ocean', 'xt_ocean')
#      long_name: surface height on T cells [Boussinesq (volume conserving) model]
#      units: meter
#      valid_range: [-32767  32767]
#      missing_value: -32768
#      _FillValue: -32768
#      packing: 4
#      scale_factor: 0.03051851
#      add_offset: 0.0
#      cell_methods: time: mean
#      time_avg_info: average_T1,average_T2,average_DT
#      coordinates: geolon_t geolat_t
#  unlimited dimensions = ('Time',)
#  current size = (121, 1500, 3600)}

# %%
ds.variables['eta_t'][:,:,0].shape
# Out:
# (121, 1500)

# %%
ds.variables['eta_t']
# Out:
# <class 'netCDF4._netCDF4._Variable'>
# int16 eta_t('Time', 'yt_ocean', 'xt_ocean')
#     long_name: surface height on T cells [Boussinesq (volume conserving) model]
#     units: meter
#     valid_range: [-32767  32767]
#     missing_value: -32768
#     _FillValue: -32768
#     packing: 4
#     scale_factor: 0.03051851
#     add_offset: 0.0
#     cell_methods: time: mean
#     time_avg_info: average_T1,average_T2,average_DT
#     coordinates: geolon_t geolat_t
# unlimited dimensions = ('Time',)
# current size = (121, 1500, 3600)

# %%
eta_t_arr.shape
# Out:
# (121, 1500, 3600)

# %%
# raise an OOM error
time_ytocean_xtocean_arr = eta_t_arr.reshape(121,1500*3600)
time_ytocean_xtocean_arr.shape
# Out:
# (121, 5400000)

# %%
time_ytocean_arr = eta_t_arr[:,:,0]
time_ytocean_arr.shape
# Out:
# (121, 1500)

# %%
time_ytocean_arr[0]
# Out:
# masked_array(data=[--, --, --, ..., -0.8239997625350952,
#                    -0.8239997625350952, -0.7629627585411072],
#              mask=[ True,  True,  True, ..., False, False, False],
#        fill_value=1e+20,
#             dtype=float32)

# %%
time_ytocean_arr[0].data
# Out:
# array([-3.2768000e+04, -3.2768000e+04, -3.2768000e+04, ...,
#        -8.2399976e-01, -8.2399976e-01, -7.6296276e-01], dtype=float32)

# %%
import statistics
statistics.median(time_ytocean_arr[0])
# Out:
# 0.06103701889514923

# %%
for i in range(0,len(time_ytocean_arr)):
    arr = time_ytocean_arr[i].data
    arr[arr == -32768] = statistics.median(time_ytocean_arr[i])

# %%
time_ytocean_arr[0].data
# Out:
# array([ 0.06103702,  0.06103702,  0.06103702, ..., -0.82399976,
#        -0.82399976, -0.76296276], dtype=float32)

# %%
# split into train & test
time_ytocean_train, time_ytocean_test = train_test_split(time_ytocean_arr.data, test_size=0.33)
time_ytocean_train.shape
# Out:
# (81, 1500)

# %%
input_size = 1500
hidden_size = 150
output_size = 1500

# %%
# fit a single layer autoencoder
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='tanh')(x)
r = Dense(output_size, activation='tanh')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1500)]            0
# _________________________________________________________________
# dense (Dense)                (None, 150)               225150
# _________________________________________________________________
# dense_1 (Dense)              (None, 1500)              226500
# =================================================================
# Total params: 451,650
# Trainable params: 451,650
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(autoencoder, "time_ytocean_autoencoder.png")

# %%
x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='tanh')(x)
r = Dense(output_size, activation='tanh')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.summary()
epochs = 100
batch_size = 1500

history = autoencoder.fit(time_ytocean_train, time_ytocean_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(time_ytocean_test, time_ytocean_test))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1500)]            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 150)               225150
# _________________________________________________________________
# dense_3 (Dense)              (None, 1500)              226500
# =================================================================
# Total params: 451,650
# Trainable params: 451,650
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.5986 - val_loss: 0.5051
# Epoch 2/100
# 1/1 [==============================] - 0s 91ms/step - loss: 0.5042 - val_loss: 0.4554
# Epoch 3/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4543 - val_loss: 0.4012
# Epoch 4/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4002 - val_loss: 0.3404
# Epoch 5/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3395 - val_loss: 0.2863
# Epoch 6/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2856 - val_loss: 0.2436
# Epoch 7/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.2430 - val_loss: 0.2104
# Epoch 8/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2098 - val_loss: 0.1843
# Epoch 9/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.1838 - val_loss: 0.1645
# Epoch 10/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1639 - val_loss: 0.1496
# Epoch 11/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1490 - val_loss: 0.1383
# Epoch 12/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1378 - val_loss: 0.1296
# Epoch 13/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1291 - val_loss: 0.1228
# Epoch 14/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.1222 - val_loss: 0.1172
# Epoch 15/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1167 - val_loss: 0.1127
# Epoch 16/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1121 - val_loss: 0.1090
# Epoch 17/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1085 - val_loss: 0.1061
# Epoch 18/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1055 - val_loss: 0.1038
# Epoch 19/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1033 - val_loss: 0.1020
# Epoch 20/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.1015 - val_loss: 0.1006
# Epoch 21/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.1002 - val_loss: 0.0993
# Epoch 22/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0990 - val_loss: 0.0982
# Epoch 23/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0979 - val_loss: 0.0972
# Epoch 24/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0968 - val_loss: 0.0962
# Epoch 25/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0959 - val_loss: 0.0954
# Epoch 26/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0950 - val_loss: 0.0946
# Epoch 27/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 28/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 29/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0931 - val_loss: 0.0930
# Epoch 30/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0927 - val_loss: 0.0926
# Epoch 31/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0923 - val_loss: 0.0923
# Epoch 32/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0920 - val_loss: 0.0920
# Epoch 33/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0917 - val_loss: 0.0917
# Epoch 34/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0914 - val_loss: 0.0914
# Epoch 35/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0911 - val_loss: 0.0911
# Epoch 36/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0908 - val_loss: 0.0908
# Epoch 37/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0906 - val_loss: 0.0906
# Epoch 38/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0903 - val_loss: 0.0904
# Epoch 39/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0902 - val_loss: 0.0903
# Epoch 40/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0900 - val_loss: 0.0901
# Epoch 41/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0898 - val_loss: 0.0900
# Epoch 42/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0897 - val_loss: 0.0899
# Epoch 43/100
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0896 - val_loss: 0.0897
# Epoch 44/100
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0894 - val_loss: 0.0896
# Epoch 45/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0893 - val_loss: 0.0895
# Epoch 46/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0892 - val_loss: 0.0894
# Epoch 47/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0891 - val_loss: 0.0893
# Epoch 48/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0890 - val_loss: 0.0892
# Epoch 49/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0889 - val_loss: 0.0891
# Epoch 50/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0888 - val_loss: 0.0890
# Epoch 51/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0887 - val_loss: 0.0889
# Epoch 52/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0886 - val_loss: 0.0888
# Epoch 53/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0885 - val_loss: 0.0887
# Epoch 54/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0884 - val_loss: 0.0886
# Epoch 55/100
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0883 - val_loss: 0.0885
# Epoch 56/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0882 - val_loss: 0.0885
# Epoch 57/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0881 - val_loss: 0.0884
# Epoch 58/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0881 - val_loss: 0.0883
# Epoch 59/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0880 - val_loss: 0.0883
# Epoch 60/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0879 - val_loss: 0.0882
# Epoch 61/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0878 - val_loss: 0.0881
# Epoch 62/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0878 - val_loss: 0.0880
# Epoch 63/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0877 - val_loss: 0.0880
# Epoch 64/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0876 - val_loss: 0.0879
# Epoch 65/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0876 - val_loss: 0.0879
# Epoch 66/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0875 - val_loss: 0.0878
# Epoch 67/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0875 - val_loss: 0.0877
# Epoch 68/100
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0874 - val_loss: 0.0877
# Epoch 69/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0873 - val_loss: 0.0876
# Epoch 70/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0873 - val_loss: 0.0876
# Epoch 71/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0872 - val_loss: 0.0875
# Epoch 72/100
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0872 - val_loss: 0.0875
# Epoch 73/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0871 - val_loss: 0.0874
# Epoch 74/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0871 - val_loss: 0.0874
# Epoch 75/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0870 - val_loss: 0.0874
# Epoch 76/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0870 - val_loss: 0.0873
# Epoch 77/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0870 - val_loss: 0.0873
# Epoch 78/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0869 - val_loss: 0.0873
# Epoch 79/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0869 - val_loss: 0.0872
# Epoch 80/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0869 - val_loss: 0.0872
# Epoch 81/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0868 - val_loss: 0.0872
# Epoch 82/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0868 - val_loss: 0.0871
# Epoch 83/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0868 - val_loss: 0.0871
# Epoch 84/100
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0867 - val_loss: 0.0871
# Epoch 85/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0867 - val_loss: 0.0870
# Epoch 86/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0867 - val_loss: 0.0870
# Epoch 87/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0866 - val_loss: 0.0870
# Epoch 88/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0866 - val_loss: 0.0870
# Epoch 89/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0866 - val_loss: 0.0870
# Epoch 90/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0866 - val_loss: 0.0869
# Epoch 91/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0866 - val_loss: 0.0869
# Epoch 92/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0865 - val_loss: 0.0869
# Epoch 93/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0865 - val_loss: 0.0869
# Epoch 94/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0865 - val_loss: 0.0869
# Epoch 95/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0865 - val_loss: 0.0869
# Epoch 96/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0865 - val_loss: 0.0868
# Epoch 97/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0865 - val_loss: 0.0868
# Epoch 98/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0864 - val_loss: 0.0868
# Epoch 99/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0864 - val_loss: 0.0868
# Epoch 100/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0864 - val_loss: 0.0868

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras
print(history.history.keys())

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
time_ytocean_test_pred = autoencoder.predict(time_ytocean_test)

# %%
time_ytocean_test_pred[0]
# Out:
# array([-0.00468464, -0.00332384, -0.002096  , ..., -0.81765985,
#        -0.8235557 , -0.7772024 ], dtype=float32)

# %%
time_ytocean_test[0]
# Out:
# array([-0.06103702, -0.06103702, -0.06103702, ..., -0.79348123,
#        -0.79348123, -0.7324442 ], dtype=float32)

# %%
n = 5
plt.figure(figsize=(25, 15))
for i in range(n):
    ax = plt.subplot(3, n, i+1)
    plt.plot(time_ytocean_test[i])

    ax = ax = plt.subplot(3, n, i+1)
    plt.plot(time_ytocean_test_pred[i])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(time_ytocean_train[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Adding more layers

# %%
input_size = 1500
hidden_size = 150
output_size = 1500

x = Input(shape=(input_size,))
hidden_1 = Dense(hidden_size, activation='relu')(x)
h = Dense(output_size, activation='relu')(hidden_1)
hidden_2 = Dense(hidden_size, activation='relu')(h)
r = Dense(output_size, activation='tanh')(hidden_2)

autoencoder_m = Model(inputs=x, outputs=r)
autoencoder_m.compile(optimizer='adam', loss='mse')

# %%
keras.utils.plot_model(autoencoder, "time_ytocean_multilayer_autoencoder.png")

# %%
epochs = 100
batch_size = 1500

history_m = autoencoder_m.fit(time_ytocean_train, time_ytocean_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(time_ytocean_test, time_ytocean_test))
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 772ms/step - loss: 0.5510 - val_loss: 0.5171
# Epoch 2/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.5215 - val_loss: 0.4824
# Epoch 3/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.4861 - val_loss: 0.4325
# Epoch 4/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4351 - val_loss: 0.3823
# Epoch 5/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.3842 - val_loss: 0.3337
# Epoch 6/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3350 - val_loss: 0.2826
# Epoch 7/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.2834 - val_loss: 0.2361
# Epoch 8/100
# 1/1 [==============================] - 0s 81ms/step - loss: 0.2367 - val_loss: 0.1976
# Epoch 9/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.1980 - val_loss: 0.1682
# Epoch 10/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1685 - val_loss: 0.1476
# Epoch 11/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1481 - val_loss: 0.1337
# Epoch 12/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.1344 - val_loss: 0.1245
# Epoch 13/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.1254 - val_loss: 0.1185
# Epoch 14/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1196 - val_loss: 0.1144
# Epoch 15/100
# 1/1 [==============================] - 0s 82ms/step - loss: 0.1156 - val_loss: 0.1112
# Epoch 16/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1125 - val_loss: 0.1085
# Epoch 17/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1098 - val_loss: 0.1061
# Epoch 18/100
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1073 - val_loss: 0.1040
# Epoch 19/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.1052 - val_loss: 0.1022
# Epoch 20/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.1033 - val_loss: 0.1007
# Epoch 21/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.1017 - val_loss: 0.0995
# Epoch 22/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1004 - val_loss: 0.0984
# Epoch 23/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0992 - val_loss: 0.0974
# Epoch 24/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0982 - val_loss: 0.0966
# Epoch 25/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0973 - val_loss: 0.0959
# Epoch 26/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0966 - val_loss: 0.0953
# Epoch 27/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0959 - val_loss: 0.0946
# Epoch 28/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0952 - val_loss: 0.0939
# Epoch 29/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0946 - val_loss: 0.0934
# Epoch 30/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0940 - val_loss: 0.0929
# Epoch 31/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0936 - val_loss: 0.0925
# Epoch 32/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 33/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 34/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0924 - val_loss: 0.0912
# Epoch 35/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0920 - val_loss: 0.0908
# Epoch 36/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0915 - val_loss: 0.0903
# Epoch 37/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0911 - val_loss: 0.0899
# Epoch 38/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0907 - val_loss: 0.0895
# Epoch 39/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0904 - val_loss: 0.0892
# Epoch 40/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0901 - val_loss: 0.0890
# Epoch 41/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0899 - val_loss: 0.0888
# Epoch 42/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0898 - val_loss: 0.0887
# Epoch 43/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0896 - val_loss: 0.0885
# Epoch 44/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0895 - val_loss: 0.0884
# Epoch 45/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0893 - val_loss: 0.0882
# Epoch 46/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0891 - val_loss: 0.0881
# Epoch 47/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0890 - val_loss: 0.0880
# Epoch 48/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0888 - val_loss: 0.0879
# Epoch 49/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0887 - val_loss: 0.0878
# Epoch 50/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0886 - val_loss: 0.0877
# Epoch 51/100
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0885 - val_loss: 0.0876
# Epoch 52/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0885 - val_loss: 0.0875
# Epoch 53/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0884 - val_loss: 0.0874
# Epoch 54/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 55/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0882 - val_loss: 0.0873
# Epoch 56/100
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0882 - val_loss: 0.0872
# Epoch 57/100
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0881 - val_loss: 0.0872
# Epoch 58/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0881 - val_loss: 0.0871
# Epoch 59/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0880 - val_loss: 0.0871
# Epoch 60/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0880 - val_loss: 0.0870
# Epoch 61/100
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0879 - val_loss: 0.0870
# Epoch 62/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0879 - val_loss: 0.0869
# Epoch 63/100
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0878 - val_loss: 0.0869
# Epoch 64/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0878 - val_loss: 0.0869
# Epoch 65/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0878 - val_loss: 0.0868
# Epoch 66/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0877 - val_loss: 0.0868
# Epoch 67/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0877 - val_loss: 0.0868
# Epoch 68/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0877 - val_loss: 0.0867
# Epoch 69/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0876 - val_loss: 0.0867
# Epoch 70/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0876 - val_loss: 0.0867
# Epoch 71/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0876 - val_loss: 0.0867
# Epoch 72/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0876 - val_loss: 0.0866
# Epoch 73/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0875 - val_loss: 0.0866
# Epoch 74/100
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0875 - val_loss: 0.0866
# Epoch 75/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0875 - val_loss: 0.0865
# Epoch 76/100
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 77/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 78/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 79/100
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0874 - val_loss: 0.0865
# Epoch 80/100
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0874 - val_loss: 0.0864
# Epoch 81/100
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 82/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 83/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 84/100
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 85/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0873 - val_loss: 0.0864
# Epoch 86/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0873 - val_loss: 0.0863
# Epoch 87/100
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 88/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 89/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 90/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 91/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 92/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 93/100
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0872 - val_loss: 0.0862
# Epoch 94/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0872 - val_loss: 0.0862
# Epoch 95/100
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0871 - val_loss: 0.0862
# Epoch 96/100
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0871 - val_loss: 0.0862
# Epoch 97/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0871 - val_loss: 0.0862
# Epoch 98/100
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0871 - val_loss: 0.0862
# Epoch 99/100
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0871 - val_loss: 0.0862
# Epoch 100/100
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0871 - val_loss: 0.0862

# %%
print(history.history.keys())

plt.plot(history_m.history['loss'])
plt.plot(history_m.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
time_ytocean_test_pred_m = autoencoder_m.predict(time_ytocean_test)
n = 5
plt.figure(figsize=(25, 15))
for i in range(n):
    ax = plt.subplot(3, n, i+1)
    plt.plot(time_ytocean_test[i])

    ax = ax = plt.subplot(3, n, i+1)
    plt.plot(time_ytocean_test_pred_m[i])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(time_ytocean_train[0])
